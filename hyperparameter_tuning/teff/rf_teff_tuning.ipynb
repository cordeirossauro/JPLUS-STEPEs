# %%
# Import list
import numpy as np
import pandas as pd
import os
import time
import itertools

os.chdir('../..')
import AstroPack as AP
os.chdir('./hyperparameter_tuning/teff')

from matplotlib import rc
rc('text', usetex=True)

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # Getting the data

# %%
# Create a list of the columns that will be used
column_list = ['TILE_ID', 'NUMBER', 'teff', 'teff_err', 'logg', 'logg_err', 'feh', 'feh_err'] + AP.Filters['JPLUS'] + AP.Filters['WISE'] + AP.Filters['GAIA']

# Import the full dataframe with stars that have both JPLUS, WISE and LAMOST data
os.chdir('../../data')
stars_raw = pd.read_csv('STEPEs Input Data.csv', usecols=column_list)
os.chdir('../hyperparameter_tuning/teff')

# Drop any row with missing values from the dataframe
stars_raw = stars_raw.dropna()

# Filter the stars according to their parameter errors
stars_raw = stars_raw[stars_raw['teff_err'] <= 300]
stars_raw = stars_raw[stars_raw['logg_err'] <= 0.2]
stars_raw = stars_raw[stars_raw['feh_err'] <= 0.4]

# %%
# Convert it into a dataframe with magnitudes and colors, indexed by the TILE ID and NUMBER of the star
stars_raw, stars = AP.AssembleWorkingDF(stars_raw, addWISE=True, addGALEX=False, addGAIA=True, Colors=True, Combinations=False)

# Get the effective temperature
teff = stars_raw['teff']

# %% [markdown]
# # Random Forest CV - Teff

# %%
# Split the full sample into training and test samples
x_develop, x_test, y_develop, y_test = train_test_split(stars, teff, test_size=0.25, random_state=42)

# %%
# Create lists with the values of each hyperparameter that will be testedn_features = [10, 45, 60, 190]
n_trees = [15, 45, 60, 190]
min_samples_leaf = [1, 10]
max_features = [0.25, 0.5, 0.75, 'auto']
criterion = ["mse"]

# Create a list containing every possible combination of hyperparameters
HPCombinations = [item for item in itertools.product(n_features, n_trees, min_samples_leaf, max_features, criterion)]

# %%
# Loop through all the hyperparameter combinations
for HPCombination in HPCombinations:
    # By doing a 4-fold, 2-repeat cross-validation, calculate the average value and the standard deviation of the error metrics 
    # and elapsed time for a model initizalized with the hyperparameter combination    
    Metrics = AP.rf_evaluator(HPCombination, x_develop, y_develop, n_splits = 4, n_repeats = 2, verbose = 1)
    
    # Save the hyperparameter combination and the evaluation results to a csv file    
    pd.DataFrame(data=(HPCombination + Metrics)).T.to_csv('rf_teff_tuning.csv', mode='a', index = False, header = False)
# Out:
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 65.944 (0.254)
# Root Mean Squared Error: 88.430  (0.447)
# Max Error: 1413.623 (234.437)
# R2 Score: 0.975 (0.000)
# Time Elapsed: 124.858 (8.846) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 65.690 (0.324)
# Root Mean Squared Error: 88.226  (0.940)
# Max Error: 1273.955 (333.563)
# R2 Score: 0.975 (0.001)
# Time Elapsed: 179.324 (11.357) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 65.838 (0.533)
# Root Mean Squared Error: 88.485  (1.492)
# Max Error: 1400.145 (265.410)
# R2 Score: 0.975 (0.001)
# Time Elapsed: 245.390 (18.686) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.055 (0.251)
# Root Mean Squared Error: 88.850  (0.866)
# Max Error: 1426.870 (277.981)
# R2 Score: 0.975 (0.001)
# Time Elapsed: 275.662 (5.973) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.467 (0.333)
# Root Mean Squared Error: 90.699  (0.979)
# Max Error: 1384.792 (276.702)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 109.641 (9.918) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.911 (0.539)
# Root Mean Squared Error: 90.024  (0.764)
# Max Error: 1398.269 (271.204)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 151.711 (7.944) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.933 (0.449)
# Root Mean Squared Error: 90.103  (1.291)
# Max Error: 1404.264 (252.526)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 190.369 (5.084) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 60, n_trees = 100, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.060 (0.461)
# Root Mean Squared Error: 90.288  (1.051)
# Max Error: 1442.296 (217.443)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 219.187 (1.982) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.176 (0.443)
# Root Mean Squared Error: 90.068  (0.540)
# Max Error: 1418.189 (281.180)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 109.309 (1.984) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.708 (0.419)
# Root Mean Squared Error: 89.493  (1.024)
# Max Error: 1356.414 (313.555)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 194.659 (2.511) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.768 (0.165)
# Root Mean Squared Error: 89.745  (0.819)
# Max Error: 1374.478 (352.494)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 281.016 (3.541) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.911 (0.386)
# Root Mean Squared Error: 89.984  (0.613)
# Max Error: 1475.824 (208.038)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 366.266 (2.691) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 68.133 (0.337)
# Root Mean Squared Error: 91.602  (0.941)
# Max Error: 1442.863 (214.342)
# R2 Score: 0.973 (0.001)
# Time Elapsed: 85.559 (1.746) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.490 (0.478)
# Root Mean Squared Error: 90.784  (0.796)
# Max Error: 1465.895 (200.501)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 160.265 (1.443) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.396 (0.264)
# Root Mean Squared Error: 90.737  (0.860)
# Max Error: 1417.608 (244.751)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 231.577 (2.791) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 50, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.432 (0.353)
# Root Mean Squared Error: 90.791  (0.845)
# Max Error: 1467.066 (191.940)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 304.947 (3.249) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.685 (0.201)
# Root Mean Squared Error: 89.443  (0.835)
# Max Error: 1417.900 (243.572)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 205.355 (3.621) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.394 (0.362)
# Root Mean Squared Error: 89.104  (0.854)
# Max Error: 1451.171 (246.455)
# R2 Score: 0.975 (0.001)
# Time Elapsed: 382.483 (5.414) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.227 (0.258)
# Root Mean Squared Error: 88.954  (0.585)
# Max Error: 1433.605 (249.020)
# R2 Score: 0.975 (0.001)
# Time Elapsed: 560.074 (9.370) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.549 (0.306)
# Root Mean Squared Error: 89.482  (0.529)
# Max Error: 1483.131 (211.145)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 750.563 (5.108) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.836 (0.479)
# Root Mean Squared Error: 91.188  (1.091)
# Max Error: 1470.992 (220.586)
# R2 Score: 0.973 (0.001)
# Time Elapsed: 163.494 (1.865) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.337 (0.367)
# Root Mean Squared Error: 90.553  (0.737)
# Max Error: 1468.311 (218.687)
# R2 Score: 0.974 (0.000)
# Time Elapsed: 313.326 (2.217) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.122 (0.213)
# Root Mean Squared Error: 90.413  (0.902)
# Max Error: 1361.931 (337.542)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 481.474 (25.318) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 190, n_trees = 100, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.267 (0.225)
# Root Mean Squared Error: 90.600  (0.836)
# Max Error: 1446.225 (238.725)
# R2 Score: 0.974 (0.001)
# Time Elapsed: 609.968 (2.708) s

# %% [markdown]
# # Graphical Analysis

# %%
hp_tuning_rf = pd.read_csv('rf_teff_tuning.csv')

x_axis = {'max_features': ['0.25', '0.5', '0.75', 'auto']}
y_axis = {'n_features': [190, 60, 45, 15]}

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = '.3f', cmap = 'Reds', v_min = 0.970, v_max = 0.976, 
                          colorbar_label='R2', colorbar_ticks = 6)

figure.savefig('rf_teff_R2_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      value_format = '.3f', cmap = 'Reds', v_min = 0.970, v_max = 0.976, 
                                      colorbar_label='R2', colorbar_ticks = 6)

figure.savefig('rf_teff_R2_heatmap (msl = 1).jpg', dpi = 250)

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = 'd', cmap = 'Reds', v_min = 65, v_max = 750, 
                          colorbar_label='time (s)', colorbar_ticks = 6)

figure.savefig('rf_teff_time_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      value_format = 'd', cmap = 'Reds', v_min = 65, v_max = 750, 
                                      colorbar_label='time (s)', colorbar_ticks = 6)

figure.savefig('rf_teff_time_heatmap (msl = 1).jpg', dpi = 250)
